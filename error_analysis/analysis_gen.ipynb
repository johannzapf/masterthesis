# %%
from utils.utils import PNode
import pandas as pd

df_sovanta = pd.read_csv("../eval_sovanta/eval-full-judgement-ref-free-cr-ar-gr-cr.csv")
df_wikieval = pd.read_csv("../eval_wikieval/eval-full-judgement-ref-free-cr-ar-gr.csv")

df_sovanta["retrieved_text"] = df_sovanta.apply(
    lambda row: " ".join([n.text for n in pd.eval(row["nodes"], local_dict={"PNode": PNode})]),
    axis=1,
)
df_sovanta["legacy_metrics"] = df_sovanta[["bleu", "rouge1", "bertscore_recall"]].mean(
    axis=1
)  # the legacy metrics that work best
df_sovanta["rag_triad"] = (
    df_sovanta["mistralai--mistral-large-instruct_answer_relevance"] * 0.5
    + df_sovanta["meta--llama3.1-70b-instruct_groundedness"] * 0.25
    + df_sovanta["meta--llama3.1-70b-instruct_context_relevance_with_cot"] * 0.25
)
df_wikieval["retrieved_text"] = df_wikieval.apply(
    lambda row: " ".join([n.text for n in pd.eval(row["nodes"], local_dict={"PNode": PNode})]),
    axis=1,
)
df_wikieval["legacy_metrics"] = df_wikieval[["bleu", "rouge1", "bertscore_recall"]].mean(
    axis=1
)  # the legacy metrics that work best
df_wikieval["rag_triad"] = (
    df_wikieval["anthropic--claude-3.7-sonnet_answer_relevance_with_cot"] * 0.25
    + df_wikieval["anthropic--claude-3.7-sonnet_groundedness_filter_trivial"] * 0.5
    + df_wikieval["gpt-4o_context_relevance_with_cot"] * 0.25
)

# %% [markdown]
# # 1. Wikieval

# %%
print(
    "Correlation with Legacy Metrics: ",
    df_wikieval["mistralai--mistral-large-instruct_judgement"].corr(df_wikieval["legacy_metrics"]),
)
print(
    "Correlation with Reference Free: ",
    df_wikieval["mistralai--mistral-large-instruct_judgement"].corr(
        df_wikieval["mistralai--mistral-large-instruct_judgement_ref_free"]
    ),
)
print(
    "Correlation with RAG Triad: ",
    df_wikieval["mistralai--mistral-large-instruct_judgement"].corr(df_wikieval["rag_triad"]),
)
# Out:
# Correlation with Legacy Metrics:  0.7175458284580102
# Correlation with Reference Free:  0.5262217269474444
# Correlation with RAG Triad:  0.22513820820080663

# %% [markdown]
# ## 1.1 Legacy Metrics

# %%
df_filtered = df_wikieval[
    [
        "chunk_size",
        "top_k",
        "rerank_model",
        "prompt",
        "answer",
        "gold_answer",
        "mistralai--mistral-large-instruct_judgement",
        "legacy_metrics",
    ]
]
df_filtered["abs_diff"] = (
    df_filtered["mistralai--mistral-large-instruct_judgement"] - df_filtered["legacy_metrics"]
).abs()
highlighted_df = df_filtered[df_filtered["abs_diff"] > 0.5]
highlighted_df
# Out:
# /var/folders/74/w68xsxd50bg_pnd9wc59zdhr0000gp/T/ipykernel_72057/3040269064.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['abs_diff'] = (df_filtered['mistralai--mistral-large-instruct_judgement'] - df_filtered['legacy_metrics']).abs()
#       chunk_size  top_k                          rerank_model  \
# 36           128      4                                   NaN
# 398          128     10  hooman650/bge-reranker-v2-m3-onnx-o4
# 797          256      8  hooman650/bge-reranker-v2-m3-onnx-o4
# 897          256     10  hooman650/bge-reranker-v2-m3-onnx-o4
# 998          256     12  hooman650/bge-reranker-v2-m3-onnx-o4
# ...          ...    ...                                   ...
# 5935         512     12                                   NaN
# 5942         512     12                                   NaN
# 5947         512     12                                   NaN
# 5960         512     12  hooman650/bge-reranker-v2-m3-onnx-o4
# 5986         512     12  hooman650/bge-reranker-v2-m3-onnx-o4
#
#                                                  prompt  \
# 36    What are some of the controversies surrounding...
# 398     What are some measures for pandemic prevention?
# 797     What are some measures for pandemic prevention?
# 897     What are some measures for pandemic prevention?
# 998     What are some measures for pandemic prevention?
# ...                                                 ...
# 5935  What are some of the controversies surrounding...
# 5942  When was GPT-4 released and what are some of i...
# 5947    What are some measures for pandemic prevention?
# 5960  What is the purpose of the Rainbow Plaque prog...
# 5986  What are some of the controversies surrounding...
#
#                                                  answer  \
# 36    Uber has been the subject of controversies inc...
# 398   Some measures for pandemic prevention include:...
# 797   Some measures for pandemic prevention include:...
# 897   Some measures for pandemic prevention include:...
# 998   Pandemic prevention measures include:\n\n*   R...
# ...                                                 ...
# 5935  Uber has been the subject of several controver...
# 5942  GPT-4 was released on March 14, 2023. Some of ...
# 5947  Measures for pandemic prevention include:\n\n1...
# 5960  The Rainbow Plaque programme in the UK is a sc...
# 5986  Uber has been the subject of several controver...
#
#                                             gold_answer  \
# 36    Uber has been involved in a number of controve...
# 398   Some measures for pandemic prevention include ...
# 797   Some measures for pandemic prevention include ...
# 897   Some measures for pandemic prevention include ...
# 998   Some measures for pandemic prevention include ...
# ...                                                 ...
# 5935  Uber has been involved in a number of controve...
# 5942  GPT-4 was released on March 14, 2023. It is a ...
# 5947  Some measures for pandemic prevention include ...
# 5960  The Rainbow Plaque programme in the UK is a sc...
# 5986  Uber has been involved in a number of controve...
#
#       mistralai--mistral-large-instruct_judgement  legacy_metrics  abs_diff
# 36                                            1.0        0.494595  0.505405
# 398                                           1.0        0.443336  0.556664
# 797                                           1.0        0.452297  0.547703
# 897                                           1.0        0.452943  0.547057
# 998                                           1.0        0.473532  0.526468
# ...                                           ...             ...       ...
# 5935                                          1.0        0.460485  0.539515
# 5942                                          1.0        0.493641  0.506359
# 5947                                          1.0        0.427995  0.572005
# 5960                                          1.0        0.492526  0.507474
# 5986                                          1.0        0.411039  0.588961
#
# [115 rows x 9 columns]

# %%
df_filtered = df_filtered[
    ~df_filtered["prompt"].isin(
        [
            "What are some of the controversies surrounding Uber?",
            "What are some measures for pandemic prevention?",
        ]
    )
]
print(
    "Correlation with Legacy Metrics: ",
    df_filtered["mistralai--mistral-large-instruct_judgement"].corr(df_filtered["legacy_metrics"]),
)
# Out:
# Correlation with Legacy Metrics:  0.7565176847381141

# %% [markdown]
# Observations:
# - 50% of errors on just one question, 30% on one more
# - errors are characterized by either long lists in the answers and/or additional information
#
# Error Classes:
# - 1: Answer contains list of detailed steps
# - 2: Answer contains additional information not found in gold answer

# %% [markdown]
# ## 1.2 Reference-free

# %%
df_filtered = df_wikieval[
    [
        "chunk_size",
        "top_k",
        "rerank_model",
        "prompt",
        "answer",
        "gold_answer",
        "mistralai--mistral-large-instruct_judgement",
        "mistralai--mistral-large-instruct_judgement_ref_free",
    ]
]
df_filtered["abs_diff"] = (
    df_filtered["mistralai--mistral-large-instruct_judgement"]
    - df_filtered["mistralai--mistral-large-instruct_judgement_ref_free"]
).abs()
highlighted_df = df_filtered[df_filtered["abs_diff"] > 0.3]
highlighted_df
# Out:
# /var/folders/74/w68xsxd50bg_pnd9wc59zdhr0000gp/T/ipykernel_72057/2400812289.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['abs_diff'] = (df_filtered['mistralai--mistral-large-instruct_judgement'] - df_filtered['mistralai--mistral-large-instruct_judgement_ref_free']).abs()
#       chunk_size  top_k                          rerank_model  \
# 406          128     12                                   NaN
# 409          128     12                                   NaN
# 456          128     12  hooman650/bge-reranker-v2-m3-onnx-o4
# 530          256      4                                   NaN
# 579          256      4  hooman650/bge-reranker-v2-m3-onnx-o4
# ...          ...    ...                                   ...
# 5556         512      4  hooman650/bge-reranker-v2-m3-onnx-o4
# 5627         512      6                                   NaN
# 5676         512      6  hooman650/bge-reranker-v2-m3-onnx-o4
# 5705         512      8                                   NaN
# 5927         512     12                                   NaN
#
#                                                  prompt  \
# 406   What is the taxonomy of Dasypoda radchenkoi, a...
# 409   What was the purpose of designing and building...
# 456   What is the taxonomy of Dasypoda radchenkoi, a...
# 530   When was the 5th Separate Guards Tatsin Red Ba...
# 579   When was the 5th Separate Guards Tatsin Red Ba...
# ...                                                 ...
# 5556  What is the main product of Fremantle Octopus ...
# 5627  Where is the type locality of the Blakistonia ...
# 5676  Where is the type locality of the Blakistonia ...
# 5705  What is the main product of Fremantle Octopus ...
# 5927  Where is the type locality of the Blakistonia ...
#
#                                                  answer  \
# 406   Die Gattung Dasypoda ist in vier Untergattunge...
# 409   The purpose of the Fiat Ecobasic concept car w...
# 456   Die Gattung Dasypoda ist in vier Untergattunge...
# 530   The 5th Separate Guards Tatsin Red Banner Orde...
# 579   The 5th Separate Guards Tatsin Red Banner Orde...
# ...                                                 ...
# 5556  Fremantle Octopus is based in Fremantle, Weste...
# 5627  The type locality of the Blakistonia plata spi...
# 5676  The type locality of the Blakistonia plata spi...
# 5705  Fremantle Octopus is based in Fremantle, Weste...
# 5927  The type locality of the Blakistonia plata spi...
#
#                                             gold_answer  \
# 406   Dasypoda radchenkoi belongs to the genus Dasyp...
# 409   The purpose of designing and building the Fiat...
# 456   Dasypoda radchenkoi belongs to the genus Dasyp...
# 530   The 5th Separate Guards Tatsin Red Banner Orde...
# 579   The 5th Separate Guards Tatsin Red Banner Orde...
# ...                                                 ...
# 5556  The main product of Fremantle Octopus is Octop...
# 5627  The type locality of the Blakistonia plata spi...
# 5676  The type locality of the Blakistonia plata spi...
# 5705  The main product of Fremantle Octopus is Octop...
# 5927  The type locality of the Blakistonia plata spi...
#
#       mistralai--mistral-large-instruct_judgement  \
# 406                                          0.75
# 409                                          1.00
# 456                                          0.75
# 530                                          1.00
# 579                                          1.00
# ...                                           ...
# 5556                                         1.00
# 5627                                         1.00
# 5676                                         1.00
# 5705                                         1.00
# 5927                                         1.00
#
#       mistralai--mistral-large-instruct_judgement_ref_free  abs_diff
# 406                                                0.25          0.5
# 409                                                0.50          0.5
# 456                                                0.25          0.5
# 530                                                0.50          0.5
# 579                                                0.50          0.5
# ...                                                 ...          ...
# 5556                                               0.50          0.5
# 5627                                               0.50          0.5
# 5676                                               0.50          0.5
# 5705                                               0.50          0.5
# 5927                                               0.50          0.5
#
# [149 rows x 9 columns]

# %%
df_filtered = df_filtered[
    ~df_filtered["prompt"].isin(
        [
            "When was the 5th Separate Guards Tatsin Red Banner Order of Suvorov Tank Brigade formed, and what is its military unit number?",
            "What was the estimated timeline for fully restoring power in Moore County after the shooting attack on the electrical distribution substations?",
        ]
    )
]
print(
    "Correlation with Legacy Metrics: ",
    df_filtered["mistralai--mistral-large-instruct_judgement"].corr(
        df_filtered["mistralai--mistral-large-instruct_judgement_ref_free"]
    ),
)
# Out:
# Correlation with Legacy Metrics:  0.571908762660549

# %% [markdown]
# Observations:
# - Errors are characterized by judgement=1 and ref_free_judgement much lower
# - 52% of errors on one question, 20% on one more
#
# Error Classes:
# - 1: Answer has different language than gold answer
# - 2: Short Answer that perfectly resembles the gold answer but may be too short for ref_free

# %% [markdown]
# ## 1.3 RAG Triad

# %%
df_filtered = df_wikieval[
    [
        "chunk_size",
        "top_k",
        "rerank_model",
        "prompt",
        "answer",
        "gold_answer",
        "mistralai--mistral-large-instruct_judgement",
        "rag_triad",
    ]
]
df_filtered["abs_diff"] = (df_filtered["mistralai--mistral-large-instruct_judgement"] - df_filtered["rag_triad"]).abs()
highlighted_df = df_filtered[df_filtered["abs_diff"] > 0.5]
highlighted_df
# Out:
# /var/folders/74/w68xsxd50bg_pnd9wc59zdhr0000gp/T/ipykernel_72057/3669053856.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['abs_diff'] = (df_filtered['mistralai--mistral-large-instruct_judgement'] - df_filtered['rag_triad']).abs()
#       chunk_size  top_k                          rerank_model  \
# 20           128      4                                   NaN
# 66           128      4  hooman650/bge-reranker-v2-m3-onnx-o4
# 76           128      4  hooman650/bge-reranker-v2-m3-onnx-o4
# 116          128      6                                   NaN
# 123          128      6                                   NaN
# ...          ...    ...                                   ...
# 4613         128      6                                   NaN
# 4712         128      8                                   NaN
# 5094         256      4  hooman650/bge-reranker-v2-m3-onnx-o4
# 5095         256      4  hooman650/bge-reranker-v2-m3-onnx-o4
# 5961         512     12  hooman650/bge-reranker-v2-m3-onnx-o4
#
#                                                  prompt  \
# 20    When was the Roanoke and Tar River Railroad fu...
# 66    What caused the crash of Yeti Airlines Flight ...
# 76    When was the Roanoke and Tar River Railroad fu...
# 116   What caused the crash of Yeti Airlines Flight ...
# 123   When was the Roanoke and Tar River Railroad fu...
# ...                                                 ...
# 4613  When did Trolleybus Route 20 in Shanghai start...
# 4712  When did Trolleybus Route 20 in Shanghai start...
# 5094  What caused the gas supply outage in Sheffield...
# 5095  What sparked the civil unrest and protests in ...
# 5961  What is the Zubaydah Trail and when was it con...
#
#                                                  answer  \
# 20    The Roanoke and Tar River Railroad was fully m...
# 66    The video taken moments before the crash showe...
# 76    The Roanoke and Tar River Railroad was fully m...
# 116   The video taken moments before the crash showe...
# 123   The Roanoke and Tar River Railroad was fully m...
# ...                                                 ...
# 4613  Trolleybus Route 20 in Shanghai started its op...
# 4712  Trolleybus Route 20 in Shanghai started its op...
# 5094  An error occurred while calling GenAIHubLLM.mi...
# 5095  An error occurred while calling GenAIHubLLM.mi...
# 5961  An error occurred while calling GenAIHubLLM.mi...
#
#                                             gold_answer  \
# 20    The Roanoke and Tar River Railroad was fully m...
# 66    The crash of Yeti Airlines Flight 691 in Pokha...
# 76    The Roanoke and Tar River Railroad was fully m...
# 116   The crash of Yeti Airlines Flight 691 in Pokha...
# 123   The Roanoke and Tar River Railroad was fully m...
# ...                                                 ...
# 4613  Trolleybus Route 20 in Shanghai started its op...
# 4712  Trolleybus Route 20 in Shanghai started its op...
# 5094  The gas supply outage in Sheffield, England in...
# 5095  The civil unrest and protests in Iran began in...
# 5961  The Zubaydah Trail, also known as the Al-Kufi ...
#
#       mistralai--mistral-large-instruct_judgement  rag_triad  abs_diff
# 20                                           0.25   1.000000  0.750000
# 66                                           0.25   0.833333  0.583333
# 76                                           0.25   1.000000  0.750000
# 116                                          0.25   0.916667  0.666667
# 123                                          0.25   1.000000  0.750000
# ...                                           ...        ...       ...
# 4613                                         0.25   0.916667  0.666667
# 4712                                         0.25   0.916667  0.666667
# 5094                                         0.00   0.750000  0.750000
# 5095                                         0.00   0.750000  0.750000
# 5961                                         0.00   0.750000  0.750000
#
# [78 rows x 9 columns]

# %% [markdown]
# Observations:
# - Errors characterized by small judgement and high RAG Triad Score
# - Errors distributed across questions
#
# Error Classes:
# - 1: Gold Answer contains more info, but answer completely answers the question
# - 2: Answer does not contain all necessary information

# %% [markdown]
# # 2. sovanta

# %%
print(
    "Correlation with Legacy Metrics: ",
    df_sovanta["meta--llama3.1-70b-instruct_judgement"].corr(df_sovanta["legacy_metrics"]),
)
print(
    "Correlation with Reference Free: ",
    df_sovanta["meta--llama3.1-70b-instruct_judgement"].corr(
        df_sovanta["meta--llama3.1-70b-instruct_judgement_ref_free"]
    ),
)
print(
    "Correlation with RAG Triad: ",
    df_sovanta["meta--llama3.1-70b-instruct_judgement"].corr(df_sovanta["rag_triad"]),
)
# Out:
# Correlation with Legacy Metrics:  0.510711497449249
# Correlation with Reference Free:  0.22283595877910636
# Correlation with RAG Triad:  0.18482855243125734

# %% [markdown]
# ## 2.1 Legacy Metrics

# %%
df_filtered = df_sovanta[
    [
        "chunk_size",
        "top_k",
        "rerank_model",
        "prompt",
        "answer",
        "gold_answer",
        "meta--llama3.1-70b-instruct_judgement",
        "legacy_metrics",
    ]
]
df_filtered["abs_diff"] = (df_filtered["meta--llama3.1-70b-instruct_judgement"] - df_filtered["legacy_metrics"]).abs()
highlighted_df = df_filtered[df_filtered["abs_diff"] > 0.5]
highlighted_df
# Out:
# /var/folders/74/w68xsxd50bg_pnd9wc59zdhr0000gp/T/ipykernel_72057/2756841943.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['abs_diff'] = (df_filtered['meta--llama3.1-70b-instruct_judgement'] - df_filtered['legacy_metrics']).abs()
#       chunk_size  top_k                          rerank_model  \
# 15           128      4                                   NaN
# 22           128      4                                   NaN
# 35           128      4                                   NaN
# 46           128      4                                   NaN
# 53           128      4                                   NaN
# ...          ...    ...                                   ...
# 7943         512     14  hooman650/bge-reranker-v2-m3-onnx-o4
# 7965         512     14  hooman650/bge-reranker-v2-m3-onnx-o4
# 7975         512     14  hooman650/bge-reranker-v2-m3-onnx-o4
# 7984         512     14  hooman650/bge-reranker-v2-m3-onnx-o4
# 7989         512     14  hooman650/bge-reranker-v2-m3-onnx-o4
#
#                                                  prompt  \
# 15            Wie beantrage ich als Werkstudent Urlaub?
# 22     wie bekomme ich eine neue maus für meinen laptop
# 35                 Welche Richtlinien gelten für Flüge?
# 46                     how do i request a miro account?
# 53    write me an agenda for a design thinking works...
# ...                                                 ...
# 7943  Darf ich bei der sovanta auch flexible Zug tic...
# 7965          wie trainiere ich meine rückenmuskulatur?
# 7975                   wie mache ich eine Krankmeldung?
# 7984  Was mach ich wenn ich die zugangskarte zum bür...
# 7989                  Gibt es bei sovanta Elektroautos?
#
#                                                  answer  \
# 15    Um als Werkstudent Urlaub zu beantragen, musst...
# 22    Die gegebenen Kontextinformationen enthalten k...
# 35    Standard class für Flüge ist coach (economy) c...
# 46    To request a Miro account, you need to create ...
# 53    Certainly! Here is an agenda for a Design Thin...
# ...                                                 ...
# 7943  Nein, laut der Travel Policy von sovanta AG mü...
# 7965  Um deine Rückenmuskulatur zu trainieren, kanns...
# 7975  Du kannst deine Krankmeldung elektronisch oder...
# 7984  Wenn du die Zugangskarte zum Büro verloren has...
# 7989  Ja, sovanta bietet Elektroautos an. Mitarbeite...
#
#                                             gold_answer  \
# 15    Du kannst mit SAP SuccessFactors einen Urlaubs...
# 22    Der Kontext enthält keine spezifischen Informa...
# 35    Es soll Economy class gebucht werden. Außerdem...
# 46    There is no specific information in the provid...
# 53    Design Thinking Workshop Agenda: Duration 3 ho...
# ...                                                 ...
# 7943  Nein, Zugtickets müssen für den günstigsten mö...
# 7965  Um Ihren Rücken zu trainieren, können sie folg...
# 7975  Du kannst deine Krankmeldung direkt über die Q...
# 7984   Der Verlust der Karte(n) ist unverzüglich und...
# 7989   Ja, es gibt bei sovanta Elektroautos als Dien...
#
#       meta--llama3.1-70b-instruct_judgement  legacy_metrics  abs_diff
# 15                                      1.0        0.352292  0.647708
# 22                                      1.0        0.427480  0.572520
# 35                                      1.0        0.345966  0.654034
# 46                                      1.0        0.361871  0.638129
# 53                                      1.0        0.355391  0.644609
# ...                                     ...             ...       ...
# 7943                                    1.0        0.465804  0.534196
# 7965                                    1.0        0.382365  0.617635
# 7975                                    1.0        0.408120  0.591880
# 7984                                    1.0        0.459627  0.540373
# 7989                                    1.0        0.351252  0.648748
#
# [1346 rows x 9 columns]

# %% [markdown]
# Observations:
# - errors are characterized by either long lists in the answers and/or additional information
#
# Error Classes:
# - 1: Answer contains list of detailed steps / elaborates way more
# - 2: Answer contains additional information not found in gold answer
# - 3: Different words are used to express the same

# %% [markdown]
# ## 2.2 Reference-free

# %%
df_filtered = df_sovanta[
    [
        "cluster",
        "chunk_size",
        "top_k",
        "rerank_model",
        "prompt",
        "answer",
        "gold_answer",
        "meta--llama3.1-70b-instruct_judgement",
        "meta--llama3.1-70b-instruct_judgement_ref_free",
    ]
]
# df_filtered = df_filtered[df_filtered["cluster"] != "UNKNOWN"]
df_filtered["abs_diff"] = (
    df_filtered["meta--llama3.1-70b-instruct_judgement"] - df_filtered["meta--llama3.1-70b-instruct_judgement_ref_free"]
).abs()
highlighted_df = df_filtered[df_filtered["abs_diff"] > 0.5]
highlighted_df
# Out:
# /var/folders/74/w68xsxd50bg_pnd9wc59zdhr0000gp/T/ipykernel_72057/3518153955.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['abs_diff'] = (df_filtered['meta--llama3.1-70b-instruct_judgement'] - df_filtered['meta--llama3.1-70b-instruct_judgement_ref_free']).abs()
#         cluster  chunk_size  top_k                          rerank_model  \
# 7       UNKNOWN         128      4                                   NaN
# 8     CONTRACTS         128      4                                   NaN
# 11    CONTRACTS         128      4                                   NaN
# 19         TECH         128      4                                   NaN
# 22      UNKNOWN         128      4                                   NaN
# ...         ...         ...    ...                                   ...
# 7906    UNKNOWN         512     14  hooman650/bge-reranker-v2-m3-onnx-o4
# 7937         HR         512     14  hooman650/bge-reranker-v2-m3-onnx-o4
# 7938    UNKNOWN         512     14  hooman650/bge-reranker-v2-m3-onnx-o4
# 7940    UNKNOWN         512     14  hooman650/bge-reranker-v2-m3-onnx-o4
# 7964    UNKNOWN         512     14  hooman650/bge-reranker-v2-m3-onnx-o4
#
#                                                  prompt  \
# 7                                Was ist das Zertikiat?
# 8     WIe lange läuft der Vertrag für EInbruchmelden...
# 11    Wie lange läuft der Vertrag für Brandmeldeanla...
# 19                                       What is Fiori?
# 22     wie bekomme ich eine neue maus für meinen laptop
# ...                                                 ...
# 7906        Wie buche eine Dienstreise bei der sovanta?
# 7937                can i fly business class to the US?
# 7938                          How do i delete a project
# 7940     can you tell me anything about the TK project?
# 7964          how can I add delivery lead to my project
#
#                                                  answer  \
# 7     Das Zertifikat ist nicht in den gegebenen Kont...
# 8     Der Vertrag für Einbruchmeldeanlagen läuft 3 J...
# 11     Der Vertrag für Brandmeldeanlagen läuft 4 Jahre.
# 19    Fiori ist die benutzerfreundliche „Designsprac...
# 22    Die gegebenen Kontextinformationen enthalten k...
# ...                                                 ...
# 7906  Es gibt keine spezifischen Informationen im Ko...
# 7937  No, according to the travel policy, the standa...
# 7938  There is no information in the provided contex...
# 7940  No information is available about the TK proje...
# 7964  To add a delivery lead to your project, you ne...
#
#                                             gold_answer  \
# 7     In den Kontextinformationen wird kein Zertifik...
# 8     Der Vertrag für Einbruchmeldeanlagen läuft 3 J...
# 11    Der Vertrag für Brandmeldeanlagen läuft für 4 ...
# 19    SAP Fiori is the user-friendly “design languag...
# 22    Der Kontext enthält keine spezifischen Informa...
# ...                                                 ...
# 7906   Die Kontextinformationen enthalten keine spez...
# 7937  No, according to the policy, the standard clas...
# 7938  The context information does not provide speci...
# 7940  There is no information about a "TK project" i...
# 7964  There is no information on how to add a delive...
#
#       meta--llama3.1-70b-instruct_judgement  \
# 7                                       1.0
# 8                                       1.0
# 11                                      1.0
# 19                                      1.0
# 22                                      1.0
# ...                                     ...
# 7906                                    1.0
# 7937                                    1.0
# 7938                                    1.0
# 7940                                    1.0
# 7964                                    0.0
#
#       meta--llama3.1-70b-instruct_judgement_ref_free  abs_diff
# 7                                               0.00      1.00
# 8                                               0.25      0.75
# 11                                              0.25      0.75
# 19                                              0.25      0.75
# 22                                              0.25      0.75
# ...                                              ...       ...
# 7906                                            0.25      0.75
# 7937                                            0.25      0.75
# 7938                                            0.25      0.75
# 7940                                            0.00      1.00
# 7964                                            0.75      0.75
#
# [824 rows x 10 columns]

# %% [markdown]
# Observations:
# - Errors are characterized by judgement=1 and ref_free_judgement much lower
# - 40% of errors are for UNKNOWN clusters -> excluded
#
# Error Classes:
# - 1: Answer has different language than gold answer
# - 2: Short Answer that perfectly resembles the gold answer but may be too short for ref_free

# %% [markdown]
# ## 2.3 RAG Triad

# %%
df_filtered = df_sovanta[
    [
        "cluster",
        "chunk_size",
        "top_k",
        "rerank_model",
        "prompt",
        "answer",
        "gold_answer",
        "meta--llama3.1-70b-instruct_judgement",
        "rag_triad",
    ]
]
# df_filtered = df_filtered[df_filtered["cluster"] != "UNKNOWN"]
df_filtered["abs_diff"] = (df_filtered["meta--llama3.1-70b-instruct_judgement"] - df_filtered["rag_triad"]).abs()
highlighted_df = df_filtered[df_filtered["abs_diff"] > 0.5]
highlighted_df
# Out:
# /var/folders/74/w68xsxd50bg_pnd9wc59zdhr0000gp/T/ipykernel_72057/705324733.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['abs_diff'] = (df_filtered['meta--llama3.1-70b-instruct_judgement'] - df_filtered['rag_triad']).abs()
#         cluster  chunk_size  top_k                          rerank_model  \
# 2         OTHER         128      4                                   NaN
# 4          TECH         128      4                                   NaN
# 7       UNKNOWN         128      4                                   NaN
# 13           HR         128      4                                   NaN
# 22      UNKNOWN         128      4                                   NaN
# ...         ...         ...    ...                                   ...
# 7965      OTHER         512     14  hooman650/bge-reranker-v2-m3-onnx-o4
# 7966         HR         512     14  hooman650/bge-reranker-v2-m3-onnx-o4
# 7970  CONTRACTS         512     14  hooman650/bge-reranker-v2-m3-onnx-o4
# 7981      OTHER         512     14  hooman650/bge-reranker-v2-m3-onnx-o4
# 7988         HR         512     14  hooman650/bge-reranker-v2-m3-onnx-o4
#
#                                                  prompt  \
# 2                        Was ist Experience Managemenet
# 4                            Was ist das GenAI Starter?
# 7                                Was ist das Zertikiat?
# 13    Wie fülle ich als STudent meinen Stundenzettel...
# 22     wie bekomme ich eine neue maus für meinen laptop
# ...                                                 ...
# 7965          wie trainiere ich meine rückenmuskulatur?
# 7966        how to get money back when traveling by car
# 7970                         How can I create a project
# 7981                                 development stages
# 7988                      Krankmeldung ab wieviel Tagen
#
#                                                  answer  \
# 2     Experience Management ist ein Bereich, der von...
# 4     Das GenAI Starter ist ein Paket, das Unternehm...
# 7     Das Zertifikat ist nicht in den gegebenen Kont...
# 13    Du füllst deinen Stundenzettel aus, indem du d...
# 22    Die gegebenen Kontextinformationen enthalten k...
# ...                                                 ...
# 7965  Um deine Rückenmuskulatur zu trainieren, kanns...
# 7966  When traveling by car, you can get money back ...
# 7970  To create a project, follow these steps:\n\n1....
# 7981  According to the Tucman Model, the development...
# 7988  Die Krankmeldung muss spätestens am 3. Krankhe...
#
#                                             gold_answer  \
# 2     Experience Management ist eine breite Diszipli...
# 4     Das GenAI Starter ist ein Starterpaket, das Un...
# 7     In den Kontextinformationen wird kein Zertifik...
# 13    Dafür verwendest du das \"Template_Stundenzett...
# 22    Der Kontext enthält keine spezifischen Informa...
# ...                                                 ...
# 7965  Um Ihren Rücken zu trainieren, können sie folg...
# 7966   To get money back when traveling by car, you ...
# 7970       Do you want to create a ZEP or Jira Project?
# 7981  There is no explicit mention of development st...
# 7988   Spätestens am 3. Krankheitstag muss eine ärzt...
#
#       meta--llama3.1-70b-instruct_judgement  rag_triad  abs_diff
# 2                                      0.00   0.666667  0.666667
# 4                                      0.25   0.875000  0.625000
# 7                                      1.00   0.250000  0.750000
# 13                                     0.25   1.000000  0.750000
# 22                                     1.00   0.166667  0.833333
# ...                                     ...        ...       ...
# 7965                                   1.00   0.280303  0.719697
# 7966                                   0.25   0.916667  0.666667
# 7970                                   0.25   0.928571  0.678571
# 7981                                   0.00   0.906250  0.906250
# 7988                                   0.25   0.875000  0.625000
#
# [1651 rows x 10 columns]

# %% [markdown]
# Observations:
# - Errors characterized by small judgement and high RAG Triad Score
# - Errors distributed across clusters, no focus on UNKNOWN
#
# Error Classes:
# - 1: Gold Answer contains more info, but answer completely answers the question
# - 2: Answer does not contain all necessary information
# - 3: Answer gives an explanation from a different angle

# %%
example_case = highlighted_df.iloc[0]
print("Prompt: ", example_case["prompt"])
print("-----------------------------\nGold Answer:\n", example_case["gold_answer"])
print("-----------------------------\nAnswer:\n", example_case["answer"])
# Out:
# Prompt:  Was ist Experience Managemenet
# -----------------------------
# Gold Answer:
#  Experience Management ist eine breite Disziplin, welche die Interkationen eines Kunden mit seinen Kunden ("CX" oder "Customer Experience"), Mitarbeitern ("EX" oder "Employee Experience") und IT Transformation ("ETX" oder "Employee Technology Experience") beinhaltet.
# -----------------------------
# Answer:
#  Experience Management ist ein Bereich, der von Andrew White (Head of Experience Management) geleitet wird und unter der Aufsicht von Christian Amendt (Program Manager, Program D) steht. Andrew setzt die strategische Richtung und ist unser Technologieexperte und Thought Leader.
